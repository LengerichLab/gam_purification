# %% [markdown]
# ### Is $X_1*X_2$ an interaction effect? If so, is $\log(X_1*X_2) = \log(X_1) + \log(X_2)$ an interaction effect?

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from gam_purification.purify import purify

# %%
x1s = np.linspace(1e-5, 1, 100)
x2s = np.linspace(1e-5, 1, 100)
intx = np.zeros((100, 100))
for i, x1 in enumerate(x1s):
    for j, x2 in enumerate(x2s):
        intx[i, j] = x1*x2

# %%
# The raw interaction looks like an interaction effect.

plt.matshow(intx, vmin=np.min(intx), vmax=np.max(intx))
plt.title("Raw Effect", fontsize=24)
plt.xlabel("X1", fontsize=18)
plt.ylabel("X2", fontsize=18)
plt.show()

# %%
# Purification demonstrates that these effects can mostly (and thus should) be represented as main effects of individual variables.
# After purification, the interaction is an XOR.

intercept, m1, m2, mat, i = purify(intx.copy(), densities=np.random.uniform(0, 1, size=intx.shape))

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(14, 6))
ax1.plot(m1)
ax1.set_title("Purified Effect of X1", fontsize=18)
ax1.set_xlabel("X1", fontsize=18)
ax1.set_ylabel("Effect", fontsize=18)

ax2.plot(m2)
ax2.set_title("Purified Effect of X2", fontsize=18)
ax2.set_xlabel("X2", fontsize=18)
ax2.set_ylabel("Effect", fontsize=18)

ax3.matshow(mat, vmin=np.min(intx), vmax=np.max(intx))
ax3.set_title("Purified Interaction", fontsize=20)
ax3.set_xlabel("X1", fontsize=18)
ax3.set_ylabel("X2", fontsize=18)
plt.tight_layout()

# %% [markdown]
# # Now let's examine $\log(X_1X_2)$

# %%
x1s = np.linspace(1e-5, 1, 100)
x2s = np.linspace(1e-5, 1, 100)
log_intx = np.zeros((100, 100))
for i, x1 in enumerate(x1s):
    for j, x2 in enumerate(x2s):
        log_intx[i, j] = np.log(x1*x2)

# %%
# The raw interaction looks like an interaction effect.

plt.matshow(log_intx, vmin=np.min(log_intx), vmax=np.max(log_intx))
plt.title("Raw Effect", fontsize=24)
plt.xlabel("X1", fontsize=18)
plt.ylabel("X2", fontsize=18)
plt.show()

# %%
# Purification demonstrates that these effects can (and thus should) be represented as main effects of individual variables.
# After purification, the interaction is empty.

intercept, m1, m2, mat, i = purify(log_intx.copy(), densities=np.random.uniform(0, 1, size=log_intx.shape))

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(14, 6))
ax1.plot(m1)
ax1.set_title("Purified Effect of X1", fontsize=18)
ax1.set_xlabel("X1", fontsize=18)
ax1.set_ylabel("Effect", fontsize=18)

ax2.plot(m2)
ax2.set_title("Purified Effect of X2", fontsize=18)
ax2.set_xlabel("X2", fontsize=18)
ax2.set_ylabel("Effect", fontsize=18)

ax3.matshow(mat, vmin=np.min(log_intx), vmax=np.max(log_intx))
ax3.set_title("Purified Interaction", fontsize=20)
ax3.set_xlabel("X1", fontsize=18)
ax3.set_ylabel("X2", fontsize=18)
plt.tight_layout()

# %% [markdown]
# This view unifies $\log(X_1X_2)$ and $X_1X_2$ -- both can be decomposed into main effects.
# For $\log(X_1X_2)$, there is no interaction left over.
# For $X_1X_2$ there is a small interaction left over if $X_1$ and $X_2$ were not centered.
